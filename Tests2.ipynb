# %% [markdown]
# # FCS Tests

# %% [markdown]
# ## Required Packages

# %%
import numpy as np
pi = np.pi
import matplotlib.pyplot as plt
# %matplotlib inline

import importlib
import pqreader.pqreader as pq # import package from local directory
importlib.reload(pq)
# Out:
# <module 'pqreader.pqreader' from 'C:\\Users\\mona\\Desktop\\pqreader\\pqreader\\pqreader.py'>

# %%
plt.rcParams.update({'font.size' : 14,
                     'axes.labelpad' : 10,
                     'xtick.major.pad': 8,
                     'xtick.major.size': 6,
                     'xtick.major.width': 1,
                     'ytick.major.size': 6,
                     'ytick.major.width': 1,
                     'xtick.minor.size': 3,
                     'xtick.minor.width': 1,
                     'ytick.minor.size': 3,
                     'ytick.minor.width': 1,
                     'axes.linewidth': 1,
                     'xtick.top' : True,
                     'xtick.direction' : 'in',
                     'ytick.right' : True,
                     'ytick.direction' : 'in',
                     'lines.linewidth' : 1.5,})

# %% [markdown]
# ## Read T3R File

# %%
timetags, route, data, metadata = pq.t3r_reader('Data/RotatingPolarizer.t3r')

# %%
fig, ax = plt.subplots(1, 1, figsize=(7,5))
ax.hist(data[np.where(route==1)], bins=100,  alpha=0.3);
ax.hist(data[np.where(route==0)], bins=100, alpha=0.3);

# %%
t0 = timetags[np.where(route==0)] # SPAD 1
t1 = timetags[np.where(route==1)] # SPAD 2

# %%
metadata['timetag_unit']*1e9 # ns
# Out:
# 100.0

# %%
t0[:10]*metadata['timetag_unit']*1e9 # ns
# Out:
# array([ 20900.,  66100., 161100., 195500., 236100., 313900., 318100.,
#        328100., 373100., 388700.])

# %%
t0_binned, _ = np.histogram(t0, bins=1000)
t1_binned, _ = np.histogram(t1, bins=1000)

# %%
fig, ax = plt.subplots(1, 1, figsize=(7,5))
ax.plot(t0_binned)
ax.plot(t1_binned)
#ax.set_xlim(0,1000)

# %%
#import multpletau_cor_tttr

# %%
fig, ax = plt.subplots(1, 1, figsize=(7,5))
ax.semilogx(ab)
#ax.set_xlim(1, 1000)

# %%
import multipletau_cor_tttr.correlate # import package from local directory
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-613-6f8ee8302a7d> in <module>()
# ----> 1 import multipletau_cor_tttr.correlate # import package from local directory
#
# ModuleNotFoundError: No module named 'multipletau_cor_tttr'
